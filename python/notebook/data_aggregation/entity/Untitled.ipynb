# %%
# %run -m ipy_startup
# %run -m ipy_logging
from mgds.data_aggregation import database as db
from mgds.data_aggregation import source as src
from mgds.data_aggregation import io_utils as io
from mgds.data_aggregation import entity
from py_utils import set_utils 
pd.set_option('display.max_info_rows', 50000000)

# %%
sources = [src.GDSC_v2, src.CCLE_v1, src.NCI60_v2]
data_types = ['gene-exome-seq', 'gene-expression', 'gene-copy-number']
m_id = entity.get_raw_entities(sources, data_types, 'CELL_LINE_ID')
# Out:
# 2016-11-21 15:07:59,275:DEBUG:mgds.data_aggregation.entity: Processing source "gdsc_v2", data type "gene-exome-seq"
# 2016-11-21 15:07:59,646:DEBUG:mgds.data_aggregation.entity: Processing source "gdsc_v2", data type "gene-expression"
# 2016-11-21 15:08:07,226:DEBUG:mgds.data_aggregation.entity: Processing source "gdsc_v2", data type "gene-copy-number"
# 2016-11-21 15:08:36,789:DEBUG:mgds.data_aggregation.entity: Processing source "ccle_v1", data type "gene-exome-seq"
# 2016-11-21 15:08:36,849:DEBUG:mgds.data_aggregation.entity: Processing source "ccle_v1", data type "gene-expression"
# 2016-11-21 15:08:39,618:DEBUG:mgds.data_aggregation.entity: Processing source "ccle_v1", data type "gene-copy-number"
# 2016-11-21 15:08:43,320:DEBUG:mgds.data_aggregation.entity: Processing source "nci60_v2", data type "gene-exome-seq"
# 2016-11-21 15:08:43,379:DEBUG:mgds.data_aggregation.entity: Processing source "nci60_v2", data type "gene-expression"
# 2016-11-21 15:08:43,624:DEBUG:mgds.data_aggregation.entity: Processing source "nci60_v2", data type "gene-copy-number"

# %%
dt = m_id[src.CCLE_v1]['gene-expression']
dt[dt['CELL_LINE_ID'].str.contains('TT')]
# Out:
#                              CELL_LINE_ID        DATA_TYPE   SOURCE
# 3551912   CCFSTTG1_CENTRAL_NERVOUS_SYSTEM  gene-expression  ccle_v1
# 35284928                TT2609C02_THYROID  gene-expression  ccle_v1
# 35323960                    TT_OESOPHAGUS  gene-expression  ccle_v1
# 35362992                       TT_THYROID  gene-expression  ccle_v1

# %%
import re
regex = re.compile('[\W_]+')
def clean(x):
    return regex.sub('', x)

def to_mgds_id(source, v):
    fn = None
    if pd.isnull(v):
        return None
    if source == src.NCI60_v2:
        return clean(v).upper().strip()
    if source == src.GDSC_v2:
        return clean(v).upper().strip()
    if source == src.CCLE_v1:
        v = v.upper().strip()
        if v == 'TT_OESOPHAGUS':
            return 'TTOESOPHAGUS'
        if v == 'TT_THYROID':
            return 'TTTHYROID'
        return v.split('_')[0].strip()
    raise ValueError('Cell line normalization for source "{}" has not been implemented yet'.format(source))

def to_mgds_ids(source, ids):
    return [to_mgds_id(source, v) for v in ids]


def aggregate(m_id):
    r = []
    for source in m_id.keys():
        for data_type, d in m_id[source].items():
            c_cl = d.filter(regex='CELL_LINE_ID').columns.tolist()
            d_id = d.copy().assign(MGDS_ID=to_mgds_ids(source, d['CELL_LINE_ID']))
            for c in c_cl:
                taxonomy = c.split(':')[1] if ':' in c else 'COMMON'
                d_pt = d_id.assign(TAXONOMY=taxonomy)[['MGDS_ID', 'DATA_TYPE', 'SOURCE', 'TAXONOMY', c]]
                d_pt = d_pt.rename(columns={c: 'CELL_LINE_ID'})
                r.append(d_pt)
    return pd.concat(r).reset_index(drop=True)

# %%
# m_id = aggregate_to_source(m_id_all)
# m_id.keys()

# %%
d_id = aggregate(m_id)

# %%
d_id.head()
# Out:
#    MGDS_ID        DATA_TYPE   SOURCE TAXONOMY                   CELL_LINE_ID
# 0   1321N1  gene-expression  ccle_v1   COMMON  1321N1_CENTRAL_NERVOUS_SYSTEM
# 1     143B  gene-expression  ccle_v1   COMMON                      143B_BONE
# 2    22RV1  gene-expression  ccle_v1   COMMON                 22RV1_PROSTATE
# 3  2313287  gene-expression  ccle_v1   COMMON                2313287_STOMACH
# 4   42MGBA  gene-expression  ccle_v1   COMMON  42MGBA_CENTRAL_NERVOUS_SYSTEM

# %%
cts = d_id.groupby(['SOURCE', 'DATA_TYPE', 'TAXONOMY', 'MGDS_ID']).size()
cts.value_counts()
# Out:
# 1    8949
# 2      20
# dtype: int64

# %%
cts[cts > 1]
# Out:
# SOURCE   DATA_TYPE         TAXONOMY  MGDS_ID
# gdsc_v2  gene-copy-number  COMMON    KMH2               2
#                                      TT                 2
#                            COSMIC    KMH2               2
#                                      TT                 2
#          gene-exome-seq    COMMON    KMH2               2
#                                      TT                 2
#                            COSMIC    KMH2               2
#                                      TT                 2
#          gene-expression   COMMON    G292CLONEA141B1    2
#                                      HEP3B217           2
#                                      NTERA2CLD1         2
#                                      PC3JPC3            2
#                                      TT                 2
#                                      UWB1289            2
#                            COSMIC    G292CLONEA141B1    2
#                                      HEP3B217           2
#                                      NTERA2CLD1         2
#                                      PC3JPC3            2
#                                      TT                 2
#                                      UWB1289            2
# dtype: int64

# %%
dt = m_id[src.GDSC_v2]['gene-expression']
dt[dt['CELL_LINE_ID'].fillna('NA').str.replace('-', '').replace('_', '').str.upper().str.contains('HEP')]
# Out:
#          CELL_LINE_ID:COSMIC CELL_LINE_ID        DATA_TYPE   SOURCE
# 5417309               909719     SK-HEP-1  gene-expression  gdsc_v2
# 14109390             1240147  Hep 3B2_1-7  gene-expression  gdsc_v2
# 14109391             1240147  Hep_3B2_1-7  gene-expression  gdsc_v2

# %%
def singlestr(x):
    assert len(x) == 1
    return x.iloc[0]
d_id_m = d_id.pivot_table(index='MGDS_ID', columns=['TAXONOMY', 'SOURCE', 'DATA_TYPE'], values='CELL_LINE_ID', aggfunc=singlestr)
d_id_m.head()
# Out:
# TAXONOMY                          COMMON                  \
# SOURCE                           ccle_v1
# DATA_TYPE               gene-copy-number  gene-exome-seq
# MGDS_ID
# 1321N1     1321N1_CENTRAL_NERVOUS_SYSTEM            None
# 143B                           143B_BONE            None
# 201T                                None            None
# 22RV1                     22RV1_PROSTATE  22RV1_PROSTATE
# 23132-87                            None            None
#
# TAXONOMY                                                                  \
# SOURCE                                            gdsc_v2
# DATA_TYPE                gene-expression gene-copy-number gene-exome-seq
# MGDS_ID
# 1321N1     1321N1_CENTRAL_NERVOUS_SYSTEM             None           None
# 143B                           143B_BONE             None           None
# 201T                                None             201T           201T
# 22RV1                     22RV1_PROSTATE            22RV1          22RV1
# 23132-87                            None         23132-87       23132-87
#
# TAXONOMY                                                                   \
# SOURCE                            nci60_v2
# DATA_TYPE gene-expression gene-copy-number gene-exome-seq gene-expression
# MGDS_ID
# 1321N1               None             None           None            None
# 143B                 None             None           None            None
# 201T                 201T             None           None            None
# 22RV1               22RV1             None           None            None
# 23132-87         23132-87             None           None            None
#
# TAXONOMY            COSMIC
# SOURCE             gdsc_v2
# DATA_TYPE gene-copy-number gene-exome-seq gene-expression
# MGDS_ID
# 1321N1                None           None            None
# 143B                  None           None            None
# 201T               1287381        1287381         1287381
# 22RV1               924100         924100          924100
# 23132-87            910924         910924          910924

# %%
d_id_m.sort_index().head(50)
# Out:
# TAXONOMY                                     COMMON  \
# SOURCE                                      ccle_v1
# DATA_TYPE                          gene-copy-number
# MGDS_ID
# 1321N1                1321N1_CENTRAL_NERVOUS_SYSTEM
# 143B                                      143B_BONE
# 201T                                           None
# 22RV1                                22RV1_PROSTATE
# 23132-87                                       None
# 2313287                             2313287_STOMACH
# 253J                                           None
# 253JBV                                         None
# 42-MG-BA                                       None
# 42MGBA                42MGBA_CENTRAL_NERVOUS_SYSTEM
# 451LU                                          None
# 5637                             5637_URINARY_TRACT
# 59M                                       59M_OVARY
# 639-V                                          None
# 639V                             639V_URINARY_TRACT
# 647-V                                          None
# 647V                             647V_URINARY_TRACT
# 697          697_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE
# 769-P                                          None
# 769P                                    769P_KIDNEY
# 786-0                                          None
# 7860                                           None
# 786O                                    786O_KIDNEY
# 8-MG-BA                                        None
# 8305C                                 8305C_THYROID
# 8505C                                 8505C_THYROID
# 8MGBA                  8MGBA_CENTRAL_NERVOUS_SYSTEM
# A101D                                    A101D_SKIN
# A172                    A172_CENTRAL_NERVOUS_SYSTEM
# A204                               A204_SOFT_TISSUE
# A2058                                    A2058_SKIN
# A253                            A253_SALIVARY_GLAND
# A2780                                   A2780_OVARY
# A3-KAW                                         None
# A375                                      A375_SKIN
# A388                                           None
# A3KAW      A3KAW_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE
# A4-FUK                                         None
# A427                                           None
# A431                                           None
# A498                                    A498_KIDNEY
# A4FUK      A4FUK_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE
# A549                                      A549_LUNG
# A673                                      A673_BONE
# A704                                    A704_KIDNEY
# ABC-1                                          None
# ABC1                                      ABC1_LUNG
# ACCMESO1                            ACCMESO1_PLEURA
# ACCS                                           None
# ACHN                                    ACHN_KIDNEY
#
# TAXONOMY                                             \
# SOURCE
# DATA_TYPE                            gene-exome-seq
# MGDS_ID
# 1321N1                                         None
# 143B                                           None
# 201T                                           None
# 22RV1                                22RV1_PROSTATE
# 23132-87                                       None
# 2313287                             2313287_STOMACH
# 253J                             253J_URINARY_TRACT
# 253JBV                         253JBV_URINARY_TRACT
# 42-MG-BA                                       None
# 42MGBA                42MGBA_CENTRAL_NERVOUS_SYSTEM
# 451LU                                          None
# 5637                             5637_URINARY_TRACT
# 59M                                       59M_OVARY
# 639-V                                          None
# 639V                             639V_URINARY_TRACT
# 647-V                                          None
# 647V                             647V_URINARY_TRACT
# 697          697_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE
# 769-P                                          None
# 769P                                    769P_KIDNEY
# 786-0                                          None
# 7860                                           None
# 786O                                    786O_KIDNEY
# 8-MG-BA                                        None
# 8305C                                 8305C_THYROID
# 8505C                                 8505C_THYROID
# 8MGBA                  8MGBA_CENTRAL_NERVOUS_SYSTEM
# A101D                                    A101D_SKIN
# A172                    A172_CENTRAL_NERVOUS_SYSTEM
# A204                               A204_SOFT_TISSUE
# A2058                                    A2058_SKIN
# A253                            A253_SALIVARY_GLAND
# A2780                                   A2780_OVARY
# A3-KAW                                         None
# A375                                      A375_SKIN
# A388                                           None
# A3KAW      A3KAW_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE
# A4-FUK                                         None
# A427                                           None
# A431                                           None
# A498                                    A498_KIDNEY
# A4FUK      A4FUK_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE
# A549                                      A549_LUNG
# A673                                      A673_BONE
# A704                                    A704_KIDNEY
# ABC-1                                          None
# ABC1                                      ABC1_LUNG
# ACCMESO1                            ACCMESO1_PLEURA
# ACCS                             ACCS_URINARY_TRACT
# ACHN                                    ACHN_KIDNEY
#
# TAXONOMY                                                              \
# SOURCE                                                       gdsc_v2
# DATA_TYPE                           gene-expression gene-copy-number
# MGDS_ID
# 1321N1                1321N1_CENTRAL_NERVOUS_SYSTEM             None
# 143B                                      143B_BONE             None
# 201T                                           None             201T
# 22RV1                                22RV1_PROSTATE            22RV1
# 23132-87                                       None         23132-87
# 2313287                             2313287_STOMACH             None
# 253J                                           None             None
# 253JBV                                         None             None
# 42-MG-BA                                       None         42-MG-BA
# 42MGBA                42MGBA_CENTRAL_NERVOUS_SYSTEM             None
# 451LU                                          None            451Lu
# 5637                             5637_URINARY_TRACT             5637
# 59M                                       59M_OVARY             None
# 639-V                                          None            639-V
# 639V                             639V_URINARY_TRACT             None
# 647-V                                          None            647-V
# 647V                             647V_URINARY_TRACT             None
# 697          697_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE              697
# 769-P                                          None            769-P
# 769P                                    769P_KIDNEY             None
# 786-0                                          None            786-0
# 7860                                           None             None
# 786O                                    786O_KIDNEY             None
# 8-MG-BA                                        None          8-MG-BA
# 8305C                                 8305C_THYROID            8305C
# 8505C                                 8505C_THYROID            8505C
# 8MGBA                  8MGBA_CENTRAL_NERVOUS_SYSTEM             None
# A101D                                    A101D_SKIN            A101D
# A172                    A172_CENTRAL_NERVOUS_SYSTEM             A172
# A204                               A204_SOFT_TISSUE             A204
# A2058                                    A2058_SKIN            A2058
# A253                            A253_SALIVARY_GLAND             A253
# A2780                                   A2780_OVARY            A2780
# A3-KAW                                         None           A3-KAW
# A375                                      A375_SKIN             A375
# A388                                           None             A388
# A3KAW      A3KAW_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE             None
# A4-FUK                                         None           A4-Fuk
# A427                                           None             A427
# A431                                           None             A431
# A498                                    A498_KIDNEY             A498
# A4FUK      A4FUK_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE             None
# A549                                      A549_LUNG             A549
# A673                                      A673_BONE             A673
# A704                                    A704_KIDNEY             A704
# ABC-1                                          None            ABC-1
# ABC1                                      ABC1_LUNG             None
# ACCMESO1                            ACCMESO1_PLEURA             None
# ACCS                                           None             None
# ACHN                                    ACHN_KIDNEY             ACHN
#
# TAXONOMY                                                                  \
# SOURCE                                           nci60_v2
# DATA_TYPE gene-exome-seq gene-expression gene-copy-number gene-exome-seq
# MGDS_ID
# 1321N1              None            None             None           None
# 143B                None            None             None           None
# 201T                201T            201T             None           None
# 22RV1              22RV1           22RV1             None           None
# 23132-87        23132-87        23132-87             None           None
# 2313287             None            None             None           None
# 253J                None            None             None           None
# 253JBV              None            None             None           None
# 42-MG-BA        42-MG-BA        42-MG-BA             None           None
# 42MGBA              None            None             None           None
# 451LU              451Lu           451Lu             None           None
# 5637                5637            5637             None           None
# 59M                 None            None             None           None
# 639-V              639-V           639-V             None           None
# 639V                None            None             None           None
# 647-V              647-V           647-V             None           None
# 647V                None            None             None           None
# 697                  697             697             None           None
# 769-P              769-P           769-P             None           None
# 769P                None            None             None           None
# 786-0              786-0           786-0             None           None
# 7860                None            None             None          786_0
# 786O                None            None             None           None
# 8-MG-BA          8-MG-BA         8-MG-BA             None           None
# 8305C              8305C           8305C             None           None
# 8505C              8505C           8505C             None           None
# 8MGBA               None            None             None           None
# A101D              A101D           A101D             None           None
# A172                A172            A172             None           None
# A204                A204            A204             None           None
# A2058              A2058           A2058             None           None
# A253                A253            A253             None           None
# A2780              A2780           A2780             None           None
# A3-KAW            A3-KAW          A3-KAW             None           None
# A375                A375            A375             None           None
# A388                A388            A388             None           None
# A3KAW               None            None             None           None
# A4-FUK            A4-Fuk          A4-Fuk             None           None
# A427                A427            A427             None           None
# A431                A431            A431             None           None
# A498                A498            A498             A498           A498
# A4FUK               None            None             None           None
# A549                A549            A549             A549           A549
# A673                A673            A673             None           None
# A704                A704            A704             None           None
# ABC-1              ABC-1           ABC-1             None           None
# ABC1                None            None             None           None
# ACCMESO1            None            None             None           None
# ACCS                None            None             None           None
# ACHN                ACHN            ACHN             ACHN           ACHN
#
# TAXONOMY                            COSMIC
# SOURCE                             gdsc_v2
# DATA_TYPE gene-expression gene-copy-number gene-exome-seq gene-expression
# MGDS_ID
# 1321N1               None             None           None            None
# 143B                 None             None           None            None
# 201T                 None          1287381        1287381         1287381
# 22RV1                None           924100         924100          924100
# 23132-87             None           910924         910924          910924
# 2313287              None             None           None            None
# 253J                 None             None           None            None
# 253JBV               None             None           None            None
# 42-MG-BA             None           687561         687561          687561
# 42MGBA               None             None           None            None
# 451LU                None          1287706        1287706         1287706
# 5637                 None           687452         687452          687452
# 59M                  None             None           None            None
# 639-V                None           906798         906798          906798
# 639V                 None             None           None            None
# 647-V                None           906797         906797          906797
# 647V                 None             None           None            None
# 697                  None           906800         906800          906800
# 769-P                None           910922         910922          910922
# 769P                 None             None           None            None
# 786-0                None           905947         905947          905947
# 7860                786_0             None           None            None
# 786O                 None             None           None            None
# 8-MG-BA              None           687562         687562          687562
# 8305C                None           906795         906795          906795
# 8505C                None           924102         924102          924102
# 8MGBA                None             None           None            None
# A101D                None           910921         910921          910921
# A172                 None           687563         687563          687563
# A204                 None           910784         910784          910784
# A2058                None           906792         906792          906792
# A253                 None           906794         906794          906794
# A2780                None           906804         906804          906804
# A3-KAW               None           910935         910935          910935
# A375                 None           906793         906793          906793
# A388                 None           910697         910697          910697
# A3KAW                None             None           None            None
# A4-FUK               None           910934         910934          910934
# A427                 None           910851         910851          910851
# A431                 None           910925         910925          910925
# A498                 A498           905948         905948          905948
# A4FUK                None             None           None            None
# A549                 A549           905949         905949          905949
# A673                 None           684052         684052          684052
# A704                 None           910920         910920          910920
# ABC-1                None           906791         906791          906791
# ABC1                 None             None           None            None
# ACCMESO1             None             None           None            None
# ACCS                 None             None           None            None
# ACHN                 ACHN           905950         905950          905950

# %%
d1 = d_id_m[('COMMON', src.NCI60_v2)].apply(lambda r: r.dropna())
d1.head()
# Out:
# DATA_TYPE gene-copy-number gene-exome-seq gene-expression
# MGDS_ID
# 1321N1                None           None            None
# 143B                  None           None            None
# 201T                  None           None            None
# 22RV1                 None           None            None
# 23132-87              None           None            None

# %%
d_id_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1901 entries, 1321N1 to ZR7530
# Data columns (total 12 columns):
# (COMMON, ccle_v1, gene-copy-number)     995 non-null object
# (COMMON, ccle_v1, gene-exome-seq)       904 non-null object
# (COMMON, ccle_v1, gene-expression)      967 non-null object
# (COMMON, gdsc_v2, gene-copy-number)     996 non-null object
# (COMMON, gdsc_v2, gene-exome-seq)       1001 non-null object
# (COMMON, gdsc_v2, gene-expression)      981 non-null object
# (COMMON, nci60_v2, gene-copy-number)    53 non-null object
# (COMMON, nci60_v2, gene-exome-seq)      60 non-null object
# (COMMON, nci60_v2, gene-expression)     54 non-null object
# (COSMIC, gdsc_v2, gene-copy-number)     996 non-null object
# (COSMIC, gdsc_v2, gene-exome-seq)       1001 non-null object
# (COSMIC, gdsc_v2, gene-expression)      981 non-null object
# dtypes: object(12)
# memory usage: 193.1+ KB

# %%
d_id = []
for src, d in m_id.items():
    print(src, d.groupby(['MGDS_ID', 'DATA_TYPE']).size().max())
    c_cl = d.filter(regex='CELL_LINE_ID').columns.tolist()
    for c in c_cl:
        print(src, c)
        taxonomy = c.split(':')[1] if ':' in c else 'COMMON'
        d_part = d.set_index(['MGDS_ID', 'DATA_TYPE'])[c].unstack()
        d_part = d_part.add_prefix(taxonomy+':')
        d_id.append(d_part)
d_id = pd.concat(d_id, axis=1, join='outer')
d_id.info()
# Out:
# ccle_v1 1
# ccle_v1 CELL_LINE_ID
# nci60_v2 1
# nci60_v2 CELL_LINE_ID
# gdsc_v2 1
# gdsc_v2 CELL_LINE_ID
# ValueErrorTraceback (most recent call last)
# <ipython-input-38-13d265480b00> in <module>()
#       6         print(src, c)
#       7         taxonomy = c.split(':')[1] if ':' in c else 'COMMON'
# ----> 8         d_part = d.set_index(['MGDS_ID', 'DATA_TYPE'])[c].unstack()
#       9         d_part = d_part.add_prefix(taxonomy+':')
#      10         d_id.append(d_part)
#
# /Users/eczech/anaconda/envs/research3.5/lib/python3.5/site-packages/pandas/core/series.py in unstack(self, level, fill_value)
#    2041         """
#    2042         from pandas.core.reshape import unstack
# -> 2043         return unstack(self, level, fill_value)
#    2044
#    2045     # ----------------------------------------------------------------------
#
# /Users/eczech/anaconda/envs/research3.5/lib/python3.5/site-packages/pandas/core/reshape.py in unstack(obj, level, fill_value)
#     405     else:
#     406         unstacker = _Unstacker(obj.values, obj.index, level=level,
# --> 407                                fill_value=fill_value)
#     408         return unstacker.get_result()
#     409
#
# /Users/eczech/anaconda/envs/research3.5/lib/python3.5/site-packages/pandas/core/reshape.py in __init__(self, values, index, level, value_columns, fill_value)
#      99
#     100         self._make_sorted_values_labels()
# --> 101         self._make_selectors()
#     102
#     103     def _make_sorted_values_labels(self):
#
# /Users/eczech/anaconda/envs/research3.5/lib/python3.5/site-packages/pandas/core/reshape.py in _make_selectors(self)
#     137
#     138         if mask.sum() < len(self.index):
# --> 139             raise ValueError('Index contains duplicate entries, '
#     140                              'cannot reshape')
#     141
#
# ValueError: Index contains duplicate entries, cannot reshape
