# %% [markdown]
# # Across-Source Gene Symbol Mapping
# **Local Version**: 1
# **Source Version**: NA
#
# Maps gene names/symbols across sources to create a global lookup table.

# %%
# %run -m ipy_startup
# %run -m ipy_logging
from mgds.data_aggregation import database as db
from mgds.data_aggregation import source as src
from mgds.data_aggregation import io_utils as io
from mgds.data_aggregation import entity
pd.set_option('display.max_info_rows', 50000000)

# %%
sources = [src.GDSC_v2, src.CCLE_v1, src.NCI60_v2, src.NCIDREAM_v1, src.TCGA_BREAST_v1]
data_types = ['gene-exome-seq', 'gene-expression', 'gene-copy-number', 'gene-rna-seq', 'gene-methylation']
m_id = entity.get_raw_entities(sources, data_types, 'GENE_ID')
# Out:
# 2016-11-28 15:28:52,290:DEBUG:mgds.data_aggregation.entity: Processing source "gdsc_v2", data type "gene-exome-seq"
# 2016-11-28 15:28:52,678:DEBUG:mgds.data_aggregation.entity: Processing source "gdsc_v2", data type "gene-expression"
# 2016-11-28 15:28:59,863:DEBUG:mgds.data_aggregation.entity: Processing source "gdsc_v2", data type "gene-copy-number"
# 2016-11-28 15:29:31,837:DEBUG:mgds.data_aggregation.entity: Processing source "gdsc_v2", data type "gene-rna-seq"
# 2016-11-28 15:29:31,838:INFO:mgds.data_aggregation.entity: Data for source "gdsc_v2" and data type "gene-rna-seq" does not exist
# 2016-11-28 15:29:31,839:DEBUG:mgds.data_aggregation.entity: Processing source "gdsc_v2", data type "gene-methylation"
# 2016-11-28 15:29:31,839:INFO:mgds.data_aggregation.entity: Data for source "gdsc_v2" and data type "gene-methylation" does not exist
# 2016-11-28 15:29:31,840:DEBUG:mgds.data_aggregation.entity: Processing source "ccle_v1", data type "gene-exome-seq"
# 2016-11-28 15:29:31,899:DEBUG:mgds.data_aggregation.entity: Processing source "ccle_v1", data type "gene-expression"
# 2016-11-28 15:29:35,611:DEBUG:mgds.data_aggregation.entity: Processing source "ccle_v1", data type "gene-copy-number"
# 2016-11-28 15:29:41,670:DEBUG:mgds.data_aggregation.entity: Processing source "ccle_v1", data type "gene-rna-seq"
# 2016-11-28 15:29:41,671:INFO:mgds.data_aggregation.entity: Data for source "ccle_v1" and data type "gene-rna-seq" does not exist
# 2016-11-28 15:29:41,671:DEBUG:mgds.data_aggregation.entity: Processing source "ccle_v1", data type "gene-methylation"
# 2016-11-28 15:29:41,672:INFO:mgds.data_aggregation.entity: Data for source "ccle_v1" and data type "gene-methylation" does not exist
# 2016-11-28 15:29:41,673:DEBUG:mgds.data_aggregation.entity: Processing source "nci60_v2", data type "gene-exome-seq"
# 2016-11-28 15:29:41,784:DEBUG:mgds.data_aggregation.entity: Processing source "nci60_v2", data type "gene-expression"
# 2016-11-28 15:29:42,100:DEBUG:mgds.data_aggregation.entity: Processing source "nci60_v2", data type "gene-copy-number"
# 2016-11-28 15:29:42,553:DEBUG:mgds.data_aggregation.entity: Processing source "nci60_v2", data type "gene-rna-seq"
# 2016-11-28 15:29:42,554:INFO:mgds.data_aggregation.entity: Data for source "nci60_v2" and data type "gene-rna-seq" does not exist
# 2016-11-28 15:29:42,554:DEBUG:mgds.data_aggregation.entity: Processing source "nci60_v2", data type "gene-methylation"
# 2016-11-28 15:29:42,555:INFO:mgds.data_aggregation.entity: Data for source "nci60_v2" and data type "gene-methylation" does not exist
# 2016-11-28 15:29:42,556:DEBUG:mgds.data_aggregation.entity: Processing source "ncidream_v1", data type "gene-exome-seq"
# 2016-11-28 15:29:42,639:DEBUG:mgds.data_aggregation.entity: Processing source "ncidream_v1", data type "gene-expression"
# 2016-11-28 15:29:43,256:DEBUG:mgds.data_aggregation.entity: Processing source "ncidream_v1", data type "gene-copy-number"
# 2016-11-28 15:29:43,730:DEBUG:mgds.data_aggregation.entity: Processing source "ncidream_v1", data type "gene-rna-seq"
# 2016-11-28 15:29:44,126:DEBUG:mgds.data_aggregation.entity: Processing source "ncidream_v1", data type "gene-methylation"
# 2016-11-28 15:29:44,303:DEBUG:mgds.data_aggregation.entity: Processing source "tcga-breast_v1", data type "gene-exome-seq"
# 2016-11-28 15:29:44,363:DEBUG:mgds.data_aggregation.entity: Processing source "tcga-breast_v1", data type "gene-expression"
# 2016-11-28 15:29:46,402:DEBUG:mgds.data_aggregation.entity: Processing source "tcga-breast_v1", data type "gene-copy-number"
# 2016-11-28 15:29:51,816:DEBUG:mgds.data_aggregation.entity: Processing source "tcga-breast_v1", data type "gene-rna-seq"
# 2016-11-28 15:29:51,817:INFO:mgds.data_aggregation.entity: Data for source "tcga-breast_v1" and data type "gene-rna-seq" does not exist
# 2016-11-28 15:29:51,817:DEBUG:mgds.data_aggregation.entity: Processing source "tcga-breast_v1", data type "gene-methylation"

# %%
# [[(k, k2, v2.columns) for k2, v2 in v.items()] for k, v in m_id.items()]

# %%
import re
regex = re.compile('[\W_]+')
def clean(x):
    return x#regex.sub('', x)

def to_mgds_id(source, v):
    fn = None
    if pd.isnull(v):
        return None
    
    # NCI-60 Special Cases
    if source == src.NCI60_v2:
        return clean(v).upper().strip()
    
    # GDSC/COSMIC Special Cases
    if source == src.GDSC_v2:
        return clean(v).upper().strip()
    
    # CCLE Special Cases
    if source == src.CCLE_v1:
        return clean(v).upper().strip()
    
    if source == src.NCIDREAM_v1:
        return clean(v).upper().strip()

    raise ValueError('Cell line normalization for source "{}" has not been implemented yet'.format(source))

def to_mgds_ids(source, ids):
    return [to_mgds_id(source, v) for v in ids]


def aggregate(m_id):
    r = []
    for source in m_id.keys():
        for data_type, d in m_id[source].items():
            c_cl = d.filter(regex='GENE_ID').columns.tolist()
            d_id = d.copy().assign(MGDS_ID=to_mgds_ids(source, d['GENE_ID:HGNC']))
            for c in c_cl:
                taxonomy = c.split(':')[1] if ':' in c else 'COMMON'
                d_pt = d_id.assign(TAXONOMY=taxonomy)[['MGDS_ID', 'DATA_TYPE', 'SOURCE', 'TAXONOMY', c]]
                d_pt = d_pt.rename(columns={c: 'GENE_ID'})
                r.append(d_pt)
    return pd.concat(r).reset_index(drop=True)

# %%
d_id = aggregate(m_id)

# Check to make sure that no gene ids from any source/data type seem to match excel dates
from mgds.data_aggregation import excel_utils
date_cts = d_id.groupby(['DATA_TYPE', 'SOURCE'])\
    .apply(lambda g: excel_utils.is_excel_date(g['GENE_ID']).value_counts())
assert True not in date_cts

# %%
d_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403512 entries, 0 to 403511
# Data columns (total 5 columns):
# MGDS_ID      403512 non-null object
# DATA_TYPE    403512 non-null object
# SOURCE       403512 non-null object
# TAXONOMY     403512 non-null object
# GENE_ID      403512 non-null object
# dtypes: object(5)
# memory usage: 15.4+ MB

# %%
# This should return no results when there are no duplicates
cts = d_id.groupby(['SOURCE', 'DATA_TYPE', 'TAXONOMY', 'MGDS_ID']).size()
print(cts.value_counts())
cts[cts > 1]
# Out:
# 1    403512
# dtype: int64
# Series([], dtype: int64)

# %%
def singlestr(x):
    assert len(x) == 1
    return x.iloc[0]
d_id_m = d_id.pivot_table(index='MGDS_ID', columns=['TAXONOMY', 'SOURCE', 'DATA_TYPE'], values='GENE_ID', aggfunc=singlestr)
d_id_m.head()
# Out:
# TAXONOMY                        CGDS                                   \
# SOURCE                       ccle_v1                         nci60_v2
# DATA_TYPE           gene-copy-number gene-expression gene-copy-number
# MGDS_ID
# 13CDNA73                        None            None             None
# 15E1.2                          None            None             None
# 182-FIP                         None            None             None
# 2'-PDE                          None            None             None
# 2001-03-01 00:00:00             None            None             None
#
# TAXONOMY                                    ENTREZ                 \
# SOURCE                                     ccle_v1       nci60_v2
# DATA_TYPE           gene-expression gene-exome-seq gene-exome-seq
# MGDS_ID
# 13CDNA73                       None           None           None
# 15E1.2                         None           None           None
# 182-FIP                        None           None           None
# 2'-PDE                         None           None           None
# 2001-03-01 00:00:00            None           None           None
#
# TAXONOMY                                         HGNC                 \
# SOURCE                   ncidream_v1          ccle_v1
# DATA_TYPE           gene-copy-number gene-copy-number gene-exome-seq
# MGDS_ID
# 13CDNA73                       10129             None           None
# 15E1.2                        283459             None           None
# 182-FIP                        57532             None           None
# 2'-PDE                          None             None           None
# 2001-03-01 00:00:00             None             None           None
#
# TAXONOMY                                ...                      \
# SOURCE                                  ...             gdsc_v2
# DATA_TYPE           gene-expression     ...      gene-exome-seq
# MGDS_ID                                 ...
# 13CDNA73                       None     ...                None
# 15E1.2                         None     ...                None
# 182-FIP                        None     ...                None
# 2'-PDE                         None     ...                None
# 2001-03-01 00:00:00            None     ...                None
#
# TAXONOMY                                                             \
# SOURCE                                      nci60_v2
# DATA_TYPE           gene-expression gene-copy-number gene-exome-seq
# MGDS_ID
# 13CDNA73                       None             None           None
# 15E1.2                         None             None           None
# 182-FIP                        None             None           None
# 2'-PDE                         None             None           None
# 2001-03-01 00:00:00            None             None           None
#
# TAXONOMY                                                             \
# SOURCE                                   ncidream_v1
# DATA_TYPE           gene-expression gene-copy-number gene-exome-seq
# MGDS_ID
# 13CDNA73                       None         13CDNA73           None
# 15E1.2                         None           15E1.2           None
# 182-FIP                        None          182-FIP           None
# 2'-PDE                         None             None           None
# 2001-03-01 00:00:00            None             None           None
#
# TAXONOMY
# SOURCE
# DATA_TYPE           gene-expression gene-methylation gene-rna-seq
# MGDS_ID
# 13CDNA73                       None             None         None
# 15E1.2                       15E1.2             None         None
# 182-FIP                        None             None         None
# 2'-PDE                       2'-PDE             None         None
# 2001-03-01 00:00:00            None             None         None
#
# [5 rows x 21 columns]

# %%
d_id_m['HGNC'].sort_index().head(50).tail(51)
# Out:
# SOURCE                       ccle_v1                                 \
# DATA_TYPE           gene-copy-number gene-exome-seq gene-expression
# MGDS_ID
# 13CDNA73                        None           None            None
# 15E1.2                          None           None            None
# 182-FIP                         None           None            None
# 2'-PDE                          None           None            None
# 2001-03-01 00:00:00             None           None            None
# 2001-09-01 00:00:00             None           None            None
# 2001-12-01 00:00:00             None           None            None
# 2002-03-01 00:00:00             None           None            None
# 2002-09-01 00:00:00             None           None            None
# 2003-03-01 00:00:00             None           None            None
# 2003-09-01 00:00:00             None           None            None
# 2004-03-01 00:00:00             None           None            None
# 2004-09-01 00:00:00             None           None            None
# 2005-03-01 00:00:00             None           None            None
# 2005-09-01 00:00:00             None           None            None
# 2006-03-01 00:00:00             None           None            None
# 2006-09-01 00:00:00             None           None            None
# 2007-03-01 00:00:00             None           None            None
# 2007-09-01 00:00:00             None           None            None
# 2008-03-01 00:00:00             None           None            None
# 2008-09-01 00:00:00             None           None            None
# 2009-03-01 00:00:00             None           None            None
# 2009-09-01 00:00:00             None           None            None
# 2010-03-01 00:00:00             None           None            None
# 2010-09-01 00:00:00             None           None            None
# 2011-03-01 00:00:00             None           None            None
# 2011-09-01 00:00:00             None           None            None
# 2012-09-01 00:00:00             None           None            None
# 2014-09-01 00:00:00             None           None            None
# 3.8-1.2                         None           None            None
# 3.8-1.3                         None           None            None
# 3.8-1.4                         None           None            None
# 3.8-1.5                         None           None            None
# 5-HT3C2                         None           None            None
# 5S_RRNA                         None           None            None
# 5_8S_RRNA                       None           None            None
# 76P                             None           None            None
# 7A5                             None           None            None
# 7SK                             None           None            None
# A1BG                            A1BG           None            A1BG
# A1BG-AS1                    A1BG-AS1           None            None
# A1CF                            A1CF           None            A1CF
# A26C1B                          None           None            None
# A2BP1                           None           None            None
# A2LD1                           None           None            None
# A2M                              A2M           None             A2M
# A2M-AS1                         None           None         A2M-AS1
# A2ML1                          A2ML1           None           A2ML1
# A2ML1-AS1                       None           None            None
# A2ML1-AS2                       None           None            None
#
# SOURCE                           gdsc_v2                                 \
# DATA_TYPE               gene-copy-number gene-exome-seq gene-expression
# MGDS_ID
# 13CDNA73                            None           None            None
# 15E1.2                              None           None            None
# 182-FIP                             None           None            None
# 2'-PDE                              None           None            None
# 2001-03-01 00:00:00  2001-03-01 00:00:00           None            None
# 2001-09-01 00:00:00  2001-09-01 00:00:00           None            None
# 2001-12-01 00:00:00  2001-12-01 00:00:00           None            None
# 2002-03-01 00:00:00  2002-03-01 00:00:00           None            None
# 2002-09-01 00:00:00  2002-09-01 00:00:00           None            None
# 2003-03-01 00:00:00  2003-03-01 00:00:00           None            None
# 2003-09-01 00:00:00  2003-09-01 00:00:00           None            None
# 2004-03-01 00:00:00  2004-03-01 00:00:00           None            None
# 2004-09-01 00:00:00  2004-09-01 00:00:00           None            None
# 2005-03-01 00:00:00  2005-03-01 00:00:00           None            None
# 2005-09-01 00:00:00  2005-09-01 00:00:00           None            None
# 2006-03-01 00:00:00  2006-03-01 00:00:00           None            None
# 2006-09-01 00:00:00  2006-09-01 00:00:00           None            None
# 2007-03-01 00:00:00  2007-03-01 00:00:00           None            None
# 2007-09-01 00:00:00  2007-09-01 00:00:00           None            None
# 2008-03-01 00:00:00  2008-03-01 00:00:00           None            None
# 2008-09-01 00:00:00  2008-09-01 00:00:00           None            None
# 2009-03-01 00:00:00  2009-03-01 00:00:00           None            None
# 2009-09-01 00:00:00  2009-09-01 00:00:00           None            None
# 2010-03-01 00:00:00  2010-03-01 00:00:00           None            None
# 2010-09-01 00:00:00  2010-09-01 00:00:00           None            None
# 2011-03-01 00:00:00  2011-03-01 00:00:00           None            None
# 2011-09-01 00:00:00  2011-09-01 00:00:00           None            None
# 2012-09-01 00:00:00  2012-09-01 00:00:00           None            None
# 2014-09-01 00:00:00  2014-09-01 00:00:00           None            None
# 3.8-1.2                             None           None            None
# 3.8-1.3                             None           None            None
# 3.8-1.4                             None           None            None
# 3.8-1.5                             None           None            None
# 5-HT3C2                             None           None            None
# 5S_RRNA                          5S_rRNA           None            None
# 5_8S_RRNA                      5_8S_rRNA           None            None
# 76P                                 None           None            None
# 7A5                                 None           None            None
# 7SK                                  7SK           None            None
# A1BG                                A1BG           A1BG            A1BG
# A1BG-AS1                            None           None            None
# A1CF                                A1CF           A1CF            A1CF
# A26C1B                              None           None            None
# A2BP1                               None           None            None
# A2LD1                              A2LD1           None            None
# A2M                                  A2M            A2M             A2M
# A2M-AS1                             None           None            None
# A2ML1                              A2ML1          A2ML1           A2ML1
# A2ML1-AS1                      A2ML1-AS1           None            None
# A2ML1-AS2                      A2ML1-AS2           None            None
#
# SOURCE                      nci60_v2                                 \
# DATA_TYPE           gene-copy-number gene-exome-seq gene-expression
# MGDS_ID
# 13CDNA73                        None           None            None
# 15E1.2                          None           None            None
# 182-FIP                         None           None            None
# 2'-PDE                          None           None            None
# 2001-03-01 00:00:00             None           None            None
# 2001-09-01 00:00:00             None           None            None
# 2001-12-01 00:00:00             None           None            None
# 2002-03-01 00:00:00             None           None            None
# 2002-09-01 00:00:00             None           None            None
# 2003-03-01 00:00:00             None           None            None
# 2003-09-01 00:00:00             None           None            None
# 2004-03-01 00:00:00             None           None            None
# 2004-09-01 00:00:00             None           None            None
# 2005-03-01 00:00:00             None           None            None
# 2005-09-01 00:00:00             None           None            None
# 2006-03-01 00:00:00             None           None            None
# 2006-09-01 00:00:00             None           None            None
# 2007-03-01 00:00:00             None           None            None
# 2007-09-01 00:00:00             None           None            None
# 2008-03-01 00:00:00             None           None            None
# 2008-09-01 00:00:00             None           None            None
# 2009-03-01 00:00:00             None           None            None
# 2009-09-01 00:00:00             None           None            None
# 2010-03-01 00:00:00             None           None            None
# 2010-09-01 00:00:00             None           None            None
# 2011-03-01 00:00:00             None           None            None
# 2011-09-01 00:00:00             None           None            None
# 2012-09-01 00:00:00             None           None            None
# 2014-09-01 00:00:00             None           None            None
# 3.8-1.2                         None           None            None
# 3.8-1.3                         None           None            None
# 3.8-1.4                         None           None            None
# 3.8-1.5                         None           None            None
# 5-HT3C2                         None           None            None
# 5S_RRNA                         None           None            None
# 5_8S_RRNA                       None           None            None
# 76P                             None           None            None
# 7A5                             None           None            None
# 7SK                             None           None            None
# A1BG                            A1BG           A1BG            None
# A1BG-AS1                        None           None        A1BG-AS1
# A1CF                            A1CF           A1CF            A1CF
# A26C1B                          None           None            None
# A2BP1                           None           None            None
# A2LD1                           None           None            None
# A2M                              A2M           None             A2M
# A2M-AS1                         None           None            None
# A2ML1                          A2ML1          A2ML1           A2ML1
# A2ML1-AS1                       None           None            None
# A2ML1-AS2                       None           None            None
#
# SOURCE                   ncidream_v1                                 \
# DATA_TYPE           gene-copy-number gene-exome-seq gene-expression
# MGDS_ID
# 13CDNA73                    13CDNA73           None            None
# 15E1.2                        15E1.2           None          15E1.2
# 182-FIP                      182-FIP           None            None
# 2'-PDE                          None           None          2'-PDE
# 2001-03-01 00:00:00             None           None            None
# 2001-09-01 00:00:00             None           None            None
# 2001-12-01 00:00:00             None           None            None
# 2002-03-01 00:00:00             None           None            None
# 2002-09-01 00:00:00             None           None            None
# 2003-03-01 00:00:00             None           None            None
# 2003-09-01 00:00:00             None           None            None
# 2004-03-01 00:00:00             None           None            None
# 2004-09-01 00:00:00             None           None            None
# 2005-03-01 00:00:00             None           None            None
# 2005-09-01 00:00:00             None           None            None
# 2006-03-01 00:00:00             None           None            None
# 2006-09-01 00:00:00             None           None            None
# 2007-03-01 00:00:00             None           None            None
# 2007-09-01 00:00:00             None           None            None
# 2008-03-01 00:00:00             None           None            None
# 2008-09-01 00:00:00             None           None            None
# 2009-03-01 00:00:00             None           None            None
# 2009-09-01 00:00:00             None           None            None
# 2010-03-01 00:00:00             None           None            None
# 2010-09-01 00:00:00             None           None            None
# 2011-03-01 00:00:00             None           None            None
# 2011-09-01 00:00:00             None           None            None
# 2012-09-01 00:00:00             None           None            None
# 2014-09-01 00:00:00             None           None            None
# 3.8-1.2                      3.8-1.2           None            None
# 3.8-1.3                      3.8-1.3           None            None
# 3.8-1.4                      3.8-1.4           None            None
# 3.8-1.5                      3.8-1.5           None            None
# 5-HT3C2                      5-HT3c2           None            None
# 5S_RRNA                         None           None            None
# 5_8S_RRNA                       None           None            None
# 76P                              76P           None            None
# 7A5                              7A5           None             7A5
# 7SK                             None           None            None
# A1BG                            A1BG           A1BG            A1BG
# A1BG-AS1                        None           None            None
# A1CF                            None           A1CF            None
# A26C1B                          None           None            None
# A2BP1                          A2BP1           None           A2BP1
# A2LD1                           None           None            None
# A2M                              A2M            A2M             A2M
# A2M-AS1                         None           None            None
# A2ML1                          A2ML1           None           A2ML1
# A2ML1-AS1                       None           None            None
# A2ML1-AS2                       None           None            None
#
# SOURCE
# DATA_TYPE           gene-methylation gene-rna-seq
# MGDS_ID
# 13CDNA73                        None         None
# 15E1.2                          None         None
# 182-FIP                         None         None
# 2'-PDE                          None         None
# 2001-03-01 00:00:00             None         None
# 2001-09-01 00:00:00             None         None
# 2001-12-01 00:00:00             None         None
# 2002-03-01 00:00:00             None         None
# 2002-09-01 00:00:00             None         None
# 2003-03-01 00:00:00             None         None
# 2003-09-01 00:00:00             None         None
# 2004-03-01 00:00:00             None         None
# 2004-09-01 00:00:00             None         None
# 2005-03-01 00:00:00             None         None
# 2005-09-01 00:00:00             None         None
# 2006-03-01 00:00:00             None         None
# 2006-09-01 00:00:00             None         None
# 2007-03-01 00:00:00             None         None
# 2007-09-01 00:00:00             None         None
# 2008-03-01 00:00:00             None         None
# 2008-09-01 00:00:00             None         None
# 2009-03-01 00:00:00             None         None
# 2009-09-01 00:00:00             None         None
# 2010-03-01 00:00:00             None         None
# 2010-09-01 00:00:00             None         None
# 2011-03-01 00:00:00             None         None
# 2011-09-01 00:00:00             None         None
# 2012-09-01 00:00:00             None         None
# 2014-09-01 00:00:00             None         None
# 3.8-1.2                         None         None
# 3.8-1.3                         None         None
# 3.8-1.4                         None         None
# 3.8-1.5                         None         None
# 5-HT3C2                         None         None
# 5S_RRNA                         None      5S_rRNA
# 5_8S_RRNA                       None    5_8S_rRNA
# 76P                             None         None
# 7A5                              7A5         None
# 7SK                             None          7SK
# A1BG                            A1BG         A1BG
# A1BG-AS1                        None         None
# A1CF                            None         A1CF
# A26C1B                          None       A26C1B
# A2BP1                          A2BP1        A2BP1
# A2LD1                           None        A2LD1
# A2M                              A2M          A2M
# A2M-AS1                         None         None
# A2ML1                          A2ML1        A2ML1
# A2ML1-AS1                       None         None
# A2ML1-AS2                       None         None

# %%
d_id_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71403 entries, 13CDNA73 to ZZZ3
# Data columns (total 21 columns):
# (CGDS, ccle_v1, gene-copy-number)          20381 non-null object
# (CGDS, ccle_v1, gene-expression)           16042 non-null object
# (CGDS, nci60_v2, gene-copy-number)         23367 non-null object
# (CGDS, nci60_v2, gene-expression)          22370 non-null object
# (ENTREZ, ccle_v1, gene-exome-seq)          2165 non-null object
# (ENTREZ, nci60_v2, gene-exome-seq)         11203 non-null object
# (ENTREZ, ncidream_v1, gene-copy-number)    27230 non-null object
# (HGNC, ccle_v1, gene-copy-number)          20381 non-null object
# (HGNC, ccle_v1, gene-exome-seq)            2165 non-null object
# (HGNC, ccle_v1, gene-expression)           16042 non-null object
# (HGNC, gdsc_v2, gene-copy-number)          46221 non-null object
# (HGNC, gdsc_v2, gene-exome-seq)            19100 non-null object
# (HGNC, gdsc_v2, gene-expression)           17419 non-null object
# (HGNC, nci60_v2, gene-copy-number)         23367 non-null object
# (HGNC, nci60_v2, gene-exome-seq)           11203 non-null object
# (HGNC, nci60_v2, gene-expression)          22370 non-null object
# (HGNC, ncidream_v1, gene-copy-number)      27230 non-null object
# (HGNC, ncidream_v1, gene-exome-seq)        11995 non-null object
# (HGNC, ncidream_v1, gene-expression)       18632 non-null object
# (HGNC, ncidream_v1, gene-methylation)      14475 non-null object
# (HGNC, ncidream_v1, gene-rna-seq)          30154 non-null object
# dtypes: object(21)
# memory usage: 12.0+ MB
